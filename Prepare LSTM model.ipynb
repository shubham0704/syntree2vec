# %% [markdown]
# ## Testing embedding models
#
# In this notebook we are going to setup our LSTM model for the word generation task.

# %%
from __future__ import print_function

import numpy as np
import gensim
import string

from keras.callbacks import LambdaCallback
from keras.layers.recurrent import LSTM
from keras.layers.embeddings import Embedding
from keras.layers import Dense, Activation
from keras.models import Sequential
from keras.utils.data_utils import get_file
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load models

# %%
word_model = gensim.models.Word2Vec.load('./data/meta-n2v/meta-n2v100MB')

# %%
pretrained_weights = word_model.wv.syn0
vocab_size, emdedding_size = pretrained_weights.shape
print('Result embedding shape:', pretrained_weights.shape)
print('Checking similar words:')

for word in ['model']:
  most_similar = ', '.join('%s (%.2f)' % (similar, dist) for similar, dist in word_model.most_similar(word)[:8])
  print('  %s -> %s' % (word, most_similar))
# Out:
# Result embedding shape: (725, 100)
# Checking similar words:
#   model -> standard (0.85), embraer (0.82), brazil (0.60), between (0.54), sum (0.52), honor (0.52), fitted (0.51), aside (0.50)

# %%
# Now for loading the corresponding amount of sentences we need to pass the number of sentences parameter
from sentence_loader import lazy_load

# %%
tokenised_sents, sents = lazy_load(chunk_size=10240)

# %%
print(len(sents))
# Out:
# 73

# %%
#ub = np.max([len(sent) for sent in tokenised_sents])

long_sents = 0
for sent in tokenised_sents:
    if len(sent) > 45:
        long_sents += 1

long_sents
# Out:
# 3

# %%
# Let this length be the upperbound. 
# reformat the sentences to have length no more than the maximum length
sentences = [sentence for sentence in tokenised_sents if len(sentence) < 45]
print(len(sentences))
# Out:
# 673

# %%
print(sentences[0])
# Out:
# ['knightmare', 'chess', 'is', 'fantasy', 'chess', 'variant', 'published', 'by', 'steve', 'jackson', 'games', 'in', '0000']

# %%
max_sentence_len = 45

def word2idx(word):
  return word_model.wv.vocab[word].index
def idx2word(idx):
  return word_model.wv.index2word[idx]

# %%
train_x = np.zeros([len(sentences), max_sentence_len], dtype=np.int32)
train_y = np.zeros([len(sentences)], dtype=np.int32)
for i, sentence in enumerate(sentences):
  for t, word in enumerate(sentence[:-1]):
    train_x[i, t] = word2idx(word)
  train_y[i] = word2idx(sentence[-1])
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)
# Out:
# train_x shape: (70, 45)
# train_y shape: (70,)

# %% [markdown]
# ### Training

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=emdedding_size, weights=[pretrained_weights]))
model.add(LSTM(units=emdedding_size))
model.add(Dense(units=vocab_size))
model.add(Activation('softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:1044: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# implement a random sampling mechanism

def sample(preds, temperature=1.0):
  if temperature <= 0:
    return np.argmax(preds)
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

def generate_next(text, num_generated=10):
  word_idxs = [word2idx(word) for word in text.lower().split()]
  for i in range(num_generated):
    prediction = model.predict(x=np.array(word_idxs))
    idx = sample(prediction[-1], temperature=0.7)
    word_idxs.append(idx)
  return ' '.join(idx2word(idx) for idx in word_idxs)
def on_epoch_end(epoch, _):
  print('\nGenerating text after epoch: %d' % epoch)
  texts = [
    'chess',
    'is',
    'fantasy',
    'by',
    'steve'
  ]
  for text in texts:
    sample = generate_next(text)
    print('%s... -> %s' % (text, sample))

# %%
model.fit(train_x, train_y,
          batch_size=128,
          epochs=20,
          callbacks=[LambdaCallback(on_epoch_end=on_epoch_end)])
# Out:
# Epoch 1/20
#
# Generating text after epoch: 0
# chess... -> chess joe points western canterbury shorts astrophysical play nothing children range
# is... -> is kenya among during broken methven affairs into season jim tone
# fantasy... -> fantasy services musical german put given requirement little laid branching shp
# by... -> by see 0000 bradford writer invented customized model among too methven
# steve... -> steve references storm going hunting cast introduction indicating can branching originally
# 70/70 [==============================] - 0s - loss: 4.4026
# Epoch 2/20
#
# Generating text after epoch: 1
# chess... -> chess consecutive style how relationship rooms sketches culture ashburton move enjoying
# is... -> is greater problems appeared strike silverware playing perform tv preference create
# fantasy... -> fantasy footnotes alter accommodation incredible behemoth orchestral perhaps will decks target
# by... -> by funders late providers death trailing introduced bill baker rhyl branch
# steve... -> steve teacher aside lineup claim refuelled faidutti embraer base fact built
# 70/70 [==============================] - 0s - loss: 4.3227
# Epoch 3/20
#
# Generating text after epoch: 2
# chess... -> chess marked rated age concepts november production foundation is possibly graduates
# is... -> is move science removed preference jet put winter play dark fa
# fantasy... -> fantasy botham did variant appear chess before working 00 created region
# by... -> by beginning different finally standards unavailable show welsh graduates before workshop
# steve... -> steve inland out age winning see near refuelled asterisk much revealed
# 70/70 [==============================] - 0s - loss: 4.2527
# Epoch 4/20
#
# Generating text after epoch: 3
# chess... -> chess going flew otherwise extremely personal delayed pt0 fixture appear successful
# is... -> is dagenham famously walked as murphy rural goalkeeper packs turbulent with
# fantasy... -> fantasy through promoted had affairs club merson viewers wales trophies silverware
# by... -> by however far own pitch sat joe battle panharmonicon variant behemoth
# steve... -> steve new chaotic turbulent voted mentioning teammates intended level may y0
# 70/70 [==============================] - 0s - loss: 4.1930
# Epoch 5/20
#
# Generating text after epoch: 4
# chess... -> chess hour consecutive number ejection choice low neville our testimonial apparently
# is... -> is courts dover engine panharmonicon rewarded brazilian moon range winter sum
# fantasy... -> fantasy uk create everton vulgar decision voted action fitted relatively nepomuk
# by... -> by default united target tydfil disagreed image special so hot by
# steve... -> steve early did experience near model tumultuous asterisk promoted flying fixture
# 70/70 [==============================] - 0s - loss: 4.1450
# Epoch 6/20
#
# Generating text after epoch: 5
# chess... -> chess oswald affairs school shuffling voted indicating now lord legal panharmonicon
# is... -> is television delayed template opponent after just schoolchildren once operate vilela
# fantasy... -> fantasy appeared regular rewarded coaching how liverpool intended return incredible only
# by... -> by chairman mathematics gloom month uk greater opening television since been
# steve... -> steve one three death early separately faidutti meet change wamira near
# 70/70 [==============================] - 0s - loss: 4.1078
# Epoch 7/20
#
# Generating text after epoch: 6
# chess... -> chess same nepomuk estimation probability generate mathematical play rhyl writer disagreed
# is... -> is branching canvey canopy management saying storm dark pop color this
# fantasy... -> fantasy firecracker still record appeared proofing have which combined age worth
# by... -> by gloom pc strike low bruno side talk perhaps seaman out
# steve... -> steve astrophysical published called been something executive going winners firecracker in
# 70/70 [==============================] - 0s - loss: 4.0774
# Epoch 8/20
#
# Generating text after epoch: 7
# chess... -> chess apparently packs default successful concerned kenya came lord measured championships
# is... -> is writer trophies beginning player claim kuwait region two goalkeepers closest
# fantasy... -> fantasy courts foundation named workshop wellington region trade goalkeeper athletics order
# by... -> by seaman courts mainly teammates side company methven paul death filming
# steve... -> steve handed after football edge where than chief potsdam torquay back
# 70/70 [==============================] - 0s - loss: 4.0528
# Epoch 9/20
#
# Generating text after epoch: 8
# chess... -> chess fitting providers be lyndhurst power main featured born jet thwart
# is... -> is proven default whitney faidutti use ejection kuwait pitch chessboard everton
# fantasy... -> fantasy geometry gloom program known demotion such winners indeed era over
# by... -> by abstract powerful cockpit production were left revived their issues jet
# steve... -> steve match hot winners games walked games seasonal french into innovation
# 70/70 [==============================] - 0s - loss: 4.0329
# Epoch 10/20
#
# Generating text after epoch: 9
# chess... -> chess becoming blank won hod courts honor mount version create decision
# is... -> is fans nightmarish something new were leeds railway tv jackson requirement
# fantasy... -> fantasy invented intended schoolchildren range geometry instruction lord packs contrast doncaster
# by... -> by united powerful hour lineup sum relatively botham cost services fitting
# steve... -> steve specific session address tags national something behind kuwait recovered it
# 70/70 [==============================] - 0s - loss: 4.0177
# Epoch 11/20
#
# Generating text after epoch: 10
# chess... -> chess the give oswald binman op tempete squares rhyl playing december
# is... -> is working workshop bars use syndication applied more syndication recovered starting
# fantasy... -> fantasy honor pun turned strike workshop constant kuwait apparently walked manchester
# by... -> by is join rovers york carrier pitch uk made use strike
# steve... -> steve jim after balanced away currently graphics era squad player opening
# 70/70 [==============================] - 0s - loss: 4.0062
# Epoch 12/20
#
# Generating text after epoch: 11
# chess... -> chess observatory math 0000s astronomer hod railway measured now torquay pilatus
# is... -> is otherwise seasonal constant crisis echiquier crew once worked basic knightmare
# fantasy... -> fantasy instrument proven cost known athletics providers style seasonal 0000 record
# by... -> by example mbe same three southall small tempete german graduates mbe
# steve... -> steve jim other shows behind choice rewarded bury played stability composed
# 70/70 [==============================] - 0s - loss: 3.9978
# Epoch 13/20
#
# Generating text after epoch: 12
# chess... -> chess behind spanned producer action zealand tucano writer finally oswald caused
# is... -> is introduction kuwait designed allows talk its crew eight each off
# fantasy... -> fantasy whitney for courts down fitted head bird torquay only ranks
# by... -> by remained return manchester fitted culture below branching defeat total internationally
# steve... -> steve cost blues jet abstract changing consisting demotion bars lauriston fixture
# 70/70 [==============================] - 0s - loss: 3.9918
# Epoch 14/20
#
# Generating text after epoch: 13
# chess... -> chess join years piece unavailable lineup his copies football geometry astrophysical
# is... -> is or months cost lineup years it states there athletic deck
# fantasy... -> fantasy worked dueling refuelled cast garrett leaves sacked pt0 record dark
# by... -> by famously silverware set balanced family introduced range student different defeat
# steve... -> steve doubt number out skiing asterisk through teenage engined referred shorts
# 70/70 [==============================] - 0s - loss: 3.9875
# Epoch 15/20
#
# Generating text after epoch: 14
# chess... -> chess referred operate caused months fixture silverware company allows cost marked
# is... -> is club appeared turned remained mentioning canopy possibly following set requirement
# fantasy... -> fantasy contemporary rural copies be skifield johann vitoria website issues relationship
# by... -> by designed fly blues example seaman dueling y0 decks blank among
# steve... -> steve referred region summer where so beginning uk different methven trade
# 70/70 [==============================] - 0s - loss: 3.9844
# Epoch 16/20
#
# Generating text after epoch: 15
# chess... -> chess rules references variant ranks leaves waiter template intended see kilometres
# is... -> is athletic decision organ named if region square hence original remained
# fantasy... -> fantasy broken february 0000 lineup cup noggin winners wolverines era decks
# by... -> by consisting branching footballer image australian nothing just sold athletic career
# steve... -> steve botham the fact island currently built wilhelm honor most around
# 70/70 [==============================] - 0s - loss: 3.9820
# Epoch 17/20
#
# Generating text after epoch: 16
# chess... -> chess hunting private embraer otherwise mathematical children for former seat figurehead
# is... -> is that becoming per carrier epitomised op order given marked squares
# fantasy... -> fantasy vulgar liverpool squad increasing side british turbulent zealand number courts
# by... -> by along voted show abstract asterisk pilatus craters turboprop deck career
# steve... -> steve characters claim dueling for seat instruction success bill echiquier removed
# 70/70 [==============================] - 0s - loss: 3.9800
# Epoch 18/20
#
# Generating text after epoch: 17
# chess... -> chess he problems this whilst shows recovered bruno steve rings when
# is... -> is regular beethoven 000 going branch fact chief new bars travelled
# fantasy... -> fantasy friend three brazilian contemporary graphics relationship seasonal 0000 place hutt
# by... -> by seats going math blues choice vilela wellington its level bill
# steve... -> steve lineup legal blank were changing battle footballer schoolchildren 00 noggin
# 70/70 [==============================] - 0s - loss: 3.9781
# Epoch 19/20
#
# Generating text after epoch: 18
# chess... -> chess executive consortium kilometres cheaper july through level built ranks dover
# is... -> is kilometres league everton moon preference accommodation engine cups cup pop
# fantasy... -> fantasy broadcast record bird performance travelled liverpool below engined had year
# by... -> by death unavailable too over different vilela athletic most when more
# steve... -> steve merthyr demotion put railhead originally states family mars as create
# 70/70 [==============================] - 0s - loss: 3.9762
# Epoch 20/20
#
# Generating text after epoch: 19
# chess... -> chess half mars came relationship referred if vulgar year returning rakaia
# is... -> is mainly brothers broken rings operate head 00 there got manager
# fantasy... -> fantasy executive use powerplant joe y0 both how blank defeat american
# by... -> by goalpost zealand board wife management its wilhelm death problems oakes
# steve... -> steve marked handed head fantasy rings those put between career personal
# 70/70 [==============================] - 0s - loss: 3.9743

# %%
# %%file lstm_model.py

from __future__ import print_function
import numpy as np

from keras.callbacks import LambdaCallback
from keras.layers.recurrent import LSTM
from keras.layers.embeddings import Embedding
from keras.layers import Dense, Activation
from keras.models import Sequential

def sample(preds, temperature=1.0):
    if temperature <= 0:
        return np.argmax(preds)
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def eval_on_lstm(tokenised_sents, word_model, max_sentence_len, test_ratio=0.2):
    
    sentences = [sentence for sentence in tokenised_sents if len(sentence) < max_sentence_len]
    pretrained_weights = word_model.wv.syn0
    vocab_size, emdedding_size = pretrained_weights.shape
    def word2idx(word):
        try:
            idx = word_model.wv.vocab[word].index
        except:
            print("word: {} not in vocab using default word card\n".format(word))
            idx = 0
        return idx
    
    def idx2word(idx):
        return word_model.wv.index2word[idx]
    
    total = len(sentences)
    train_size = int(total * (1 - test_ratio))
    test_size = total - train_size
    
    train_x = np.zeros([train_size, max_sentence_len], dtype=np.int32)
    train_y = np.zeros([train_size], dtype=np.int32)
    test_x = np.zeros([test_size, max_sentence_len], dtype=np.int32)
    test_y = np.zeros([test_size], dtype=np.int32)

    for i, sentence in enumerate(sentences[:train_size]):
        for t, word in enumerate(sentence[:-1]):
            train_x[i, t] = word2idx(word)
        train_y[i] = word2idx(sentence[-1])
    for i, sentence in enumerate(sentences[train_size:]):
        for t, word in enumerate(sentence[:-1]):
            test_x[i, t] = word2idx(word)
        test_y[i] = word2idx(sentence[-1])
    
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=emdedding_size, weights=[pretrained_weights]))
    model.add(LSTM(units=emdedding_size))
    model.add(Dense(units=vocab_size))
    model.add(Activation('softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
    
    def generate_next(text, num_generated=10):
        word_idxs = [word2idx(word) for word in text.lower().split()]
        for i in range(num_generated):
            prediction = model.predict(x=np.array(word_idxs))
            idx = sample(prediction[-1], temperature=0.7)
            word_idxs.append(idx)
        return ' '.join(idx2word(idx) for idx in word_idxs)
    
    def on_epoch_end(epoch, _):
        print('\nGenerating text after epoch: %d' % epoch)
        texts = [
        'chess',
        'is',
        'fantasy',
        'by',
        'steve',
        'lasting'
        ]
        for text in texts:
            sample = generate_next(text)
            print('%s... -> %s' % (text, sample))
            
    model.fit(train_x, train_y,
          batch_size=128,
          epochs=20,
          callbacks=[LambdaCallback(on_epoch_end=on_epoch_end)])
    
    scores = model.evaluate(test_x, test_y, verbose=0)
    print("Accuracy of the model is {}".format(scores))
# Out:
# Overwriting lstm_model.py

# %%
from lstm_model import eval_on_lstm
# Out:
# Using TensorFlow backend.

# %%
eval_on_lstm(tokenised_sents,word_model, 40)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:1044: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Epoch 1/20
#
# Generating text after epoch: 0
# chess... -> chess blues professional his bruno months starting vilela awarded move blank
# is... -> is uk sat cost redbridge figurehead winning throughout funders epitomised producer
# fantasy... -> fantasy revealed aircraft he default producer pt rural defeat otherwise steve
# by... -> by it 0000s workshop doncaster different concerned friend more lyndhurst pun
# steve... -> steve in there fitting desired kuwait bird writer off culture published
# lasting... -> lasting games teenage little accommodation lower which wilhelm version using championships
# 54/54 [==============================] - 0s - loss: 6.5822
# Epoch 2/20
#
# Generating text after epoch: 1
# chess... -> chess little rural life travelled wife former hutt rewarded goalkeepers awarded
# is... -> is hutt states rare translation greater revived total from the blues
# fantasy... -> fantasy offer success shuffling sharp athletic schoolchildren tone different flew got
# by... -> by goalkeepers southend football over still both far created greater wishes
# steve... -> steve potsdam it ballooning chess mount andy fitting template andy mathematical
# lasting... -> lasting just promoted something cost tv bars finally writer new mathematical
# 54/54 [==============================] - 0s - loss: 6.5593
# Epoch 3/20
#
# Generating text after epoch: 2
# chess... -> chess template relationship panharmonicon management will epitomised pull tucano television engine
# is... -> is target uk silverware desired incredible squares record whitney affairs powerful
# fantasy... -> fantasy show edge addition ashburton from being away operated probability rural
# by... -> by fractions opening former contemporary named game in contrast hence referred
# steve... -> steve air different place sketches panharmonicon brazil european epitomised until of
# lasting... -> lasting powerful moves requirement malzel llandudno since increasing garrett color teacher
# 54/54 [==============================] - 0s - loss: 6.5342
# Epoch 4/20
#
# Generating text after epoch: 3
# chess... -> chess parodies broken tumultuous revived three consecutive marked chaotic 0000 kenya
# is... -> is might channel indeed color variant he edge vulgar recently before
# fantasy... -> fantasy he dueling children arthur different y0 games when laid wamira
# by... -> by wishes possibly two graphics australian using proven own cups uses
# steve... -> steve region player martin successful through level sketches example other counting
# lasting... -> lasting seat edoras predecessor example appearances decks uk month all following
# 54/54 [==============================] - 0s - loss: 6.5046
# Epoch 5/20
#
# Generating text after epoch: 4
# chess... -> chess by everton relatively player coaching other man use color home
# is... -> is southall graphics rovers trainer had place both opening personal thwart
# fantasy... -> fantasy sur graphics tempete after season schoolchildren sharp student translation broken
# by... -> by desired wamira play andy 000 johann spanned bird 0000s rural
# steve... -> steve estimation might children trophies flying otherwise also vulgar enjoying martin
# lasting... -> lasting packs y0 thurman referred says as early pop image 0000
# 54/54 [==============================] - 0s - loss: 6.4675
# Epoch 6/20
#
# Generating text after epoch: 5
# chess... -> chess york llandudno new methven lower york hutt was match vitoria
# is... -> is 0000shp city pierre athletics op thwart filming aircraft around intended
# fantasy... -> fantasy special newly will children trailing methven regular half teach show
# by... -> by and family our level standards brazil among baker surprise lineup
# steve... -> steve defeat among astrophysical dormant following possibly got fitting potsdam september
# lasting... -> lasting there requests was playing by more paintings wilhelm piece wamira
# 54/54 [==============================] - 0s - loss: 6.4188
# Epoch 7/20
#
# Generating text after epoch: 6
# chess... -> chess string turboprop athletics swiss career between those number skiing otherwise
# is... -> is flying color potsdam mathematics comprised called month down rewarded united
# fantasy... -> fantasy pun total national sacked stoke in stoke over blank merthyr
# by... -> by fixture jackson voted change beethoven recently baker mount death athletics
# steve... -> steve baker year out confirmed trophies sum llandudno math generate on
# lasting... -> lasting bury lie canopy now connell action baker famously football fitted
# 54/54 [==============================] - 0s - loss: 6.3530
# Epoch 8/20
#
# Generating text after epoch: 7
# chess... -> chess combinatorics changing following particularly internationally region late three revived rated
# is... -> is but claim broken other referred rewarded successful board enjoying own
# fantasy... -> fantasy lie university mbe moon going clequin league such also endurance
# by... -> by commemorate crew panharmonicon among crisis by 000 british otherwise year
# steve... -> steve flying seat by in life meet as built late born
# lasting... -> lasting strike arthur rules southall voted line uk laid applied love
# 54/54 [==============================] - 0s - loss: 6.2638
# Epoch 9/20
#
# Generating text after epoch: 8
# chess... -> chess ashburton goalkeeper include he winter three jim jim consisting did
# is... -> is man requests multiple blank fitted time faidutti love athletic shp
# fantasy... -> fantasy perhaps marked loyalty silverware production board jim introduced similarly steve
# by... -> by this an developed remained variant handed defeat manchester school op
# steve... -> steve european adaptation orchestral both generate becoming workshop specific another bury
# lasting... -> lasting attraction came children innovation teach love squares ranks garrett place
# 54/54 [==============================] - 0s - loss: 6.1455
# Epoch 10/20
#
# Generating text after epoch: 9
# chess... -> chess originally contrast per sum after endurance same paintings uses consecutive
# is... -> is until viewers confirmed aside age shuffling fitting going removed composed
# fantasy... -> fantasy style mentioning attraction after on jim celtic on particularly other
# by... -> by accommodation shown turboprop fa may create blues molesey the incredible
# steve... -> steve liverpool 0000 much city behind hence wellington years staff played
# lasting... -> lasting tone brazil until endurance beyond tydfil national career says was
# 54/54 [==============================] - 0s - loss: 5.9972
# Epoch 11/20
#
# Generating text after epoch: 10
# chess... -> chess perform after fantasy into canada hastings vilela record thwart which
# is... -> is saying contrast revealed malzel brothers york below battle op asterisk
# fantasy... -> fantasy game sells bird cup are talk pc management particularly affairs
# by... -> by indicating consortium mk choice embraer producer observatory changing lower all
# steve... -> steve hod total create moon medals paintings appearances organ moon aircraft
# lasting... -> lasting zealand pop torquay finally region coaching consortium player thwart winning
# 54/54 [==============================] - 0s - loss: 5.8262
# Epoch 12/20
#
# Generating text after epoch: 11
# chess... -> chess however lord customized 000 jackson own been david era town
# is... -> is most honor his family hunting lord former little higher shown
# fantasy... -> fantasy back different edge zealand fantasy put ashburton just one bruno
# by... -> by graphics england former neville north provost sorties line rooms returning
# steve... -> steve copy month parodies set adaptation rural innovation fa wellesley only
# lasting... -> lasting private still wilhelm celtic opponent schoolchildren its popular composed against
# 54/54 [==============================] - 0s - loss: 5.6451
# Epoch 13/20
#
# Generating text after epoch: 12
# chess... -> chess nightmarish friend fly transfer blues victory skifield channel university remained
# is... -> is november prevent figurehead marked family huddersfield revived opponent several is
# fantasy... -> fantasy op pbs south can goals waiter standards unavailable copy orchestral
# by... -> by brazilian graduates paintings fly seats december university 00 rovers walked
# steve... -> steve botham out flying goalkeeper trade friend rules given turboprop engined
# lasting... -> lasting celtic australian back crew ex pitch than blues services north
# 54/54 [==============================] - 0s - loss: 5.4657
# Epoch 14/20
#
# Generating text after epoch: 13
# chess... -> chess chess faidutti our shrewsbury home powerful requests square engined have
# is... -> is away bruno through town indicating pbs channel point says successful
# fantasy... -> fantasy half storm steve ballooning use place february action brazil be
# by... -> by transformation canopy region medals david low handicap 0000 requests apparently
# steve... -> steve television rovers crisis left island malzel mechanical accommodation famously to
# lasting... -> lasting or cheaper than going torquay color martin panharmonicon llandudno andy
# 54/54 [==============================] - 0s - loss: 5.2946
# Epoch 15/20
#
# Generating text after epoch: 14
# chess... -> chess andy opponent since blank kenya version pieces german customized says
# is... -> is tucano recently wellington viewers featured career cartoonish off spanned kenya
# fantasy... -> fantasy daughter used model engined mathematical cast repair abstract graphics explanation
# by... -> by says syndication tv however coaching default fitting appeared awarded commemorate
# steve... -> steve children thwart merthyr dagenham dagenham using sacked did returning how
# lasting... -> lasting card tumultuous seasonal national defeat knightmare from such was entered
# 54/54 [==============================] - 0s - loss: 5.1323
# Epoch 16/20
#
# Generating text after epoch: 15
# chess... -> chess working tydfil wales edge indeed range may or in bill
# is... -> is embraer image pierre goalkeepers england developed was foundation enjoying johann
# fantasy... -> fantasy career southend referred sat ashburton engine bury newly knightmare november
# by... -> by powerful undergoes may translation rogerio children cheaper parodies merthyr served
# steve... -> steve made marked instrument malzel of travelled fly tone made issues
# lasting... -> lasting version disagreed syndication teacher at relationship referred desired bruno website
# 54/54 [==============================] - 0s - loss: 4.9759
# Epoch 17/20
#
# Generating text after epoch: 16
# chess... -> chess cast different leaves unavailable sorties turned hot explanation lower region
# is... -> is malzel handicap edge appear chaotic era 000 turbulent still german
# fantasy... -> fantasy place noggin asterisk copy our club carrier legal friend summer
# by... -> by model over noggin wellesley be made rare level pierre caps
# steve... -> steve jackson bill attraction branching talk figurehead such revived wales southall
# lasting... -> lasting shows hunting david company requests edge club professional both hod
# 54/54 [==============================] - 0s - loss: 4.8250
# Epoch 18/20
#
# Generating text after epoch: 17
# chess... -> chess by indeed pratt travelled deal per swiss andy 0000shp with
# is... -> is months botham legal designed silverware canada marked balanced canopy possibly
# fantasy... -> fantasy championships canvey courts handicap mk something paintings marked example is
# by... -> by provost voted intended recovered embraer commemorate competitions school however oakes
# steve... -> steve match mk huddersfield given early caps might mk strongly rated
# lasting... -> lasting southall deal services flew hastings wife indicating each botham bird
# 54/54 [==============================] - 0s - loss: 4.6803
# Epoch 19/20
#
# Generating text after epoch: 18
# chess... -> chess named thwart faidutti to more so range skifield further culture
# is... -> is into redbridge are adaptation their how player winners appearances science
# fantasy... -> fantasy championships connell its filming both squad winter endurance artist his
# by... -> by per appearances sulking uses got measured sum power deck cafes
# steve... -> steve flew lower december sold counting fa player schoolchildren management nepomuk
# lasting... -> lasting united bars echiquier late 0000shp enjoying translation moon through canterbury
# 54/54 [==============================] - 0s - loss: 4.5409
# Epoch 20/20
#
# Generating text after epoch: 19
# chess... -> chess used see something probability 0000s murphy famously selected fractions at
# is... -> is sharp 000 counting range probability sketches mars main have had
# fantasy... -> fantasy town sat until rules requests teammates shuffling revealed moves created
# by... -> by rhyl working tv played foundation rules blues zealand the pieces
# steve... -> steve bird pc cockpit paul template given branch wilhelm remained return
# lasting... -> lasting comprised michigan delayed level german change foundation known graduates brazilian
# 54/54 [==============================] - 0s - loss: 4.4083
# Accuracy of the model is 7.00911569595

# %%
# now lets test the 1Mb model of syntactic_n2v
from sentence_loader import lazy_load
tokenised_sents, sents = lazy_load(chunk_size=1048576/2)

# %%
len(sents)
# Out:
# 8

# %%
from lstm_model import eval_on_lstm
# Out:
# Using TensorFlow backend.

# %%
import gensim

# %%
word_model = gensim.models.Word2Vec.load('./data/syncode/syncode_model_1MB')
eval_on_lstm(tokenised_sents,word_model, 40)
# Out:
# word: ibm not in vocab using default word card
#
# word: 000mm not in vocab using default word card
#
# word: antenna not in vocab using default word card
#
# word: wmvp not in vocab using default word card
#
# word: anna not in vocab using default word card
#
# word: backquotes not in vocab using default word card
#
# word: Ruo not in vocab using default word card
#
# word: Lin not in vocab using default word card
#
# word: Guang not in vocab using default word card
#
# word: Xing not in vocab using default word card
#
# word: ponna not in vocab using default word card
#
# word: ponna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: 00m not in vocab using default word card
#
# word: Da not in vocab using default word card
#
# word: Tai not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: Tai not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: Ri not in vocab using default word card
#
# word: Ben not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: 000b not in vocab using default word card
#
# word: ilidza not in vocab using default word card
#
# word: h0k not in vocab using default word card
#
# word: Gao not in vocab using default word card
#
# word: Yao not in vocab using default word card
#
# word: Shi not in vocab using default word card
#
# word: font not in vocab using default word card
#
# word: 0b not in vocab using default word card
#
# word: maginot not in vocab using default word card
#
# word: Zu not in vocab using default word card
#
# word: Yu not in vocab using default word card
#
# word: Jun not in vocab using default word card
#
# word: Ji not in vocab using default word card
#
# word: Tian not in vocab using default word card
#
# word: Jun not in vocab using default word card
#
# word: Jin not in vocab using default word card
#
# word: Li not in vocab using default word card
#
# word: Jun not in vocab using default word card
#
# word: Nan not in vocab using default word card
#
# word: Tiao not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Jin not in vocab using default word card
#
# word: Zhuang not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: He not in vocab using default word card
#
# word: Ye not in vocab using default word card
#
# word: Cun not in vocab using default word card
#
# word: Zhao not in vocab using default word card
#
# word: Ri not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Gong not in vocab using default word card
#
# word: Qi not in vocab using default word card
#
# word: Cun not in vocab using default word card
#
# word: Zhi not in vocab using default word card
#
# word: Tian not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Qing not in vocab using default word card
#
# word: Shui not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: San not in vocab using default word card
#
# word: Fang not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Shang not in vocab using default word card
#
# word: Zhong not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Da not in vocab using default word card
#
# word: Fan not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:1044: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Epoch 1/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 9.1928
# Generating text after epoch: 0
# chess... -> chess institutionalists smiley ur method fleeing rupaka grouped hughes films aachen
# is... -> is rebels bearing don navigable flooding potts citing plat coercion kaga
# fantasy... -> fantasy duryodhana simplest zhaoqing peruvian europa hiroyuki notation ma device gerrard
# by... -> by lebel dohc cranberries spectacularly nitzan disputed users methodology organism edmund
# steve... -> steve adjacent line stark accident railway cobscook toulon chakravathi eighty adomnan
# lasting... -> lasting mange phlegraean propel projectile apocalypse speculator dress selection inscription nearer
# 2804/2804 [==============================] - 8s - loss: 9.1766
# Epoch 2/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.6624
# Generating text after epoch: 1
# chess... -> chess models reich courses hambly happened st fluorescence diversity line pierre
# is... -> is nikola vigilante powder kb alter took tydfil lemisha upon upon
# fantasy... -> fantasy madison duplicates practices peasants instances offramps loan dvd ismail gas
# by... -> by elderly eschews emeryville object articulate norman strongest splashed its lennier
# steve... -> steve nitrate gilberts installment orish prose illumina professional competition multiplication downward
# lasting... -> lasting electric oregon agencies landmark dscs trails passive thornall demonstrations chase
# 2804/2804 [==============================] - 7s - loss: 7.6630
# Epoch 3/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.2320
# Generating text after epoch: 2
# chess... -> chess explanation transcripts repression go used equals did lauderdale tale extensive
# is... -> is lucy passed ticket turn pavement metals length otto intervene dewey
# fantasy... -> fantasy advance koreans mobilized continuation cubed militia dwell notably motto easily
# by... -> by figure trends slobodan acceptance bhashabhushana account mess gary house top
# steve... -> steve via page career contents senteced pacifica lifespan altitude indecently preparations
# lasting... -> lasting focuses misbehaviour dot moose liverpool admiralty physical efforts knezevic dived
# 2804/2804 [==============================] - 8s - loss: 7.2336
# Epoch 4/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1672
# Generating text after epoch: 3
# chess... -> chess overall kanasugalu itself bilingual cheerful leonard bob dissolved fenton weeks
# is... -> is epistle battlion now consolidation annexed attempts autonomous transition mica perspective
# fantasy... -> fantasy travelling differ maryland swim fundy politics expression upholstery trudeau davidovic
# by... -> by definite parkway seventy domingo broadcasting gault exact silva bailed quoddy
# steve... -> steve contribute anatomy crackdowns fundy crusaders cousins occupation form enlightenment arrested
# lasting... -> lasting fc silence happens powerplant kurt repeats commitment deciding forming hayes
# 2804/2804 [==============================] - 8s - loss: 7.1741
# Epoch 5/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1441
# Generating text after epoch: 4
# chess... -> chess founder done links literal rejects locomotive correct industrialism paragraph gankiyam
# is... -> is utilizing dukovic right adjoint rochester selection interviews newton clinton nomination
# fantasy... -> fantasy leads tourists ballinger sitcom tough deer refuelled sebring centered stores
# by... -> by xiangwu sense sacramento housing artists morris hal buena maude hon
# steve... -> steve kb motion meelah monitor powder their basketball need wertheim quadratic
# lasting... -> lasting remarks urban arose thoughts chances cities way nadu cup lizzie
# 2804/2804 [==============================] - 8s - loss: 7.1541
# Epoch 6/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1423
# Generating text after epoch: 5
# chess... -> chess exposition family degradation order life disputed knives stigma illegally transmission
# is... -> is suffered humble methods brink superior ruiri outcome km lazar lives
# fantasy... -> fantasy priest layers nonpartisan nitrate masti slightly guys stevens quo hunt
# by... -> by holding scotia refuse chessboard transforming whose renovation stretch superalgebra richmond
# steve... -> steve girls defending barbados crisis mountains ready supplements altering slide dewar
# lasting... -> lasting baked kary discuss lizzie temporarily damage denomination avoids serve vomma
# 2804/2804 [==============================] - 8s - loss: 7.1441
# Epoch 7/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1283
# Generating text after epoch: 6
# chess... -> chess fondation kevin drivetrain street outcome hits persisting number differs disputes
# is... -> is stuttering sandstone year proved shaping frederick list rochester bath commanders
# fantasy... -> fantasy ovaj lanes rakaia wamira exterior way ark really terminology islands
# by... -> by peaked last hurd realism set gully pilatus tabernacle mysterious compromised
# steve... -> steve nanjo housewife categorized sullivan byname kannada tasked pipes affixed money
# lasting... -> lasting remote township transformation today vismistananda hearts coast eastbound affiliation epidemic
# 2804/2804 [==============================] - 8s - loss: 7.1384
# Epoch 8/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1367
# Generating text after epoch: 7
# chess... -> chess springs developed threatening friendly asking raja assisting hartwick lines hoping
# is... -> is powerful roret limbs abc personally battlefield detailed ephod flight shown
# fantasy... -> fantasy attempt jagadhekamalla etobicoke equals james proceeding guthrie diametrically enterprise dogs
# by... -> by sailed model garages measure relevant refit echoes macc etait bailed
# steve... -> steve dormancy blacklist placing elected steal amberley dissemination series sections prisoner
# lasting... -> lasting amberley opel james shreds timber briefcase listed enter ruhr orrin
# 2804/2804 [==============================] - 9s - loss: 7.1367
# Epoch 9/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1310
# Generating text after epoch: 8
# chess... -> chess site enhanced retaken wilderness bonded communism instead represented remade rhythm
# is... -> is unedited krishnasharma pieces degrees usage cup lohse villa tacit asuwa
# fantasy... -> fantasy close homeland visual rebirth crutchley observed prefecure league cleaned flag
# by... -> by was velimirovic pump seas average rorting spins graduates provided important
# steve... -> steve listen nucleotides know uncertainty sits bodies meaning deployed colonization junker
# lasting... -> lasting communication cheerful compiling commit roads enhancements from presson architect conviction
# 2804/2804 [==============================] - 8s - loss: 7.1353
# Epoch 10/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1236
# Generating text after epoch: 9
# chess... -> chess that martial myles according seats batch psychologically lesson relations characterization
# is... -> is assassins years spanned lunar guns kersovani manual defenseless betrayal bright
# fantasy... -> fantasy winningham grujic asymmetric gadol rural teammates characteristics antisymmetric sceptical jonesville
# by... -> by pieces limit responders park unable lofty god playoffs bachelor folded
# steve... -> steve firing heat carhouse joshua squares goalkeeper conviction weakness clothing rules
# lasting... -> lasting 0c sin hans lifespan tawi skeeter quartered better teammates aim
# 2804/2804 [==============================] - 8s - loss: 7.1303
# Epoch 11/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1178
# Generating text after epoch: 10
# chess... -> chess talk roster thereby underpinned inherited diseases wary redundant p00 kid
# is... -> is unique airways strength guinea botanists space them tiergarten expense siula
# fantasy... -> fantasy self arithmetic dasa pittsburgh stjepan researches sovereignty duties pocahontas hegemony
# by... -> by poverty noticed formal branded foundations ko consolidation buada sarajevo chapter
# steve... -> steve exposition farmland desert artist consciousness groom defenceman scandal ono trajectory
# lasting... -> lasting ono ignitions bonus loosely tmyamkung compound penzance jeffrey ws0 sea
# 2804/2804 [==============================] - 8s - loss: 7.1292
# Epoch 12/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1196
# Generating text after epoch: 11
# chess... -> chess srivijaya counterparts romania behest steep treatment mythical invented denoting yielding
# is... -> is bomber papp repeat looking negotin potok miller 00 spa behavior
# fantasy... -> fantasy ahead politics feeding salvaged tool tamed stojan pratt viewed arriving
# by... -> by chase pease fury beans humanity unify radiation hermitian invisible karen
# steve... -> steve zara eons naturally disillusioned chaplin evolving renewal ceramics beukeboom burns
# lasting... -> lasting offenders life bright left wits polyester override statutory v0 oh
# 2804/2804 [==============================] - 8s - loss: 7.1282
# Epoch 13/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1275
# Generating text after epoch: 12
# chess... -> chess done kloetze goal holocaust benson rodriguez postfix poet achieving ws0
# is... -> is supported shou phenomenon ruirech expansion card etic freeing battleships mckellar
# fantasy... -> fantasy battles mechanoreceptors hideyori subshrubs different illness heftel dancing granite asterisk
# by... -> by items small complicated brigadier love above jin borbidge pachitch ashburton
# steve... -> steve media happy doctrine swap vault nothing size undisturbed rampage surprising
# lasting... -> lasting dundas tumultuous shankar anabaptist flowing portrayals rationality date ark suburb
# 2804/2804 [==============================] - 8s - loss: 7.1277
# Epoch 14/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1285
# Generating text after epoch: 13
# chess... -> chess joins hours often discernable cap content remarked presumably told japanese
# is... -> is good ilija reappoint transforming dropped promised terry deem merson paid
# fantasy... -> fantasy ends golf aside convicted promises afghanistan disabled event cv auspices
# by... -> by mcnaughton screenwriter constructed concrete devastating kill council hosts pickle home
# steve... -> steve platform statue catalytic roundabout hemisphere liners invisible dedicated colony sather
# lasting... -> lasting las forward faidutti radiolabels transit displaced resigning kjerulf bath litany
# 2804/2804 [==============================] - 8s - loss: 7.1266
# Epoch 15/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1175
# Generating text after epoch: 14
# chess... -> chess saluting question synods motets transmissions promised spokeswoman dramatic goods assaults
# is... -> is subtraction prime purported devils iso clean literature fbi domnall animals
# fantasy... -> fantasy conquistador differ template arrives willed spokesperson roster screw fever retired
# by... -> by hero victims camera reduction epic zara title diverse condemned orbit
# steve... -> steve watch borghese perfect australian amount agency siersdorf vaudeville jones accessory
# lasting... -> lasting tall spurred minister boat noted francisco boasts veera patch yukol
# 2804/2804 [==============================] - 8s - loss: 7.1284
# Epoch 16/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1197
# Generating text after epoch: 15
# chess... -> chess anecdotes bell basing increased expressed alternately beukeboom keeping kolpak vinas
# is... -> is behaviour consolidation backer royal isigny windshield merit pig convoy backers
# fantasy... -> fantasy spinal tom property idea cantor applaud owe monotonous vikramarjuna metals
# by... -> by fourth speakers counterpart displays anything abraham mystery specified mcconnell vigilantism
# steve... -> steve lyell commonwealth promoting demonstrated decks remix shelves sonnalige chooses collection
# lasting... -> lasting yapparungalakkarigai spending hilbert bridges operands stayed favorite sizeof genre employers
# 2804/2804 [==============================] - 8s - loss: 7.1251
# Epoch 17/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1245
# Generating text after epoch: 16
# chess... -> chess prime myles the opposed concentration devotee ceo altering green nick
# is... -> is reality exist raghavanga menagei debut linear opus convertible figurate exist
# fantasy... -> fantasy young policy superflow ono cameo vulgar interactive purely nearer serbia
# by... -> by midi exerted crown recreation abuse ability suppose pampa lubec mutiny
# steve... -> steve florence doubt kn fm geilenkirchen elle appropriately pop britain quechua
# lasting... -> lasting sortied speculate share waste contacted horticultural kelowna lowry officials ensuing
# 2804/2804 [==============================] - 9s - loss: 7.1254
# Epoch 18/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1278
# Generating text after epoch: 17
# chess... -> chess enough indira grant figure defect three serbia lyndon entrance witness
# is... -> is rush insanity madagascar merhtens register smugglers penny quite haydon cameos
# fantasy... -> fantasy volunteers prior plates club fenton heftel leuca hour readers centuries
# by... -> by deer campaing advance steal yerba frequent fluorescent track organism operations
# steve... -> steve mariamma destruction recanted chalukya tender modes olfaction experiments share wanted
# lasting... -> lasting neighborhoods premise amanda graduate enhance gen weekday refusal bra container
# 2804/2804 [==============================] - 8s - loss: 7.1215
# Epoch 19/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1227
# Generating text after epoch: 18
# chess... -> chess trekking seriously perl footbridge canted obtained dab jump breastplate bilums
# is... -> is fatalities boosters scores spirit conductor quarters christianity passengers antisubmarine flagship
# fantasy... -> fantasy brandy torque floor hierarchy guillam implication encoding cherished record holiday
# by... -> by photograph swords pre descended nelson light dimples debut users gaines
# steve... -> steve prachya recompense move representatives subshrubs sandwich schoolchildren adamant cargo antilinear
# lasting... -> lasting bias scholarly clontarf medal chip posted neo marauders discoveries explores
# 2804/2804 [==============================] - 8s - loss: 7.1227
# Epoch 20/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1085
# Generating text after epoch: 19
# chess... -> chess invisibility intensively zoological fj sides hippies leonard johnston optimized battle
# is... -> is metaphorical shikinami says cobscook paris primitive abandoned age imperials falls
# fantasy... -> fantasy squeezing later limits attachment clash allows mormacport pulled elders tahou
# by... -> by monaco gabled mange undetected overkings zujovic shou phlegra reagan vocals
# steve... -> steve held teeth egging percentage concerto fir feminist miyazaki outstanding stagg
# lasting... -> lasting fields twelfth linking tompkins consolidation nocturnal similar hotels philologist it
# 2804/2804 [==============================] - 8s - loss: 7.1219
# Accuracy of the model is 11.1500234332

# %%
word_model = gensim.models.Word2Vec.load('./data/w2v/w2v_model_1MB')
eval_on_lstm(tokenised_sents,word_model, 40)
# Out:
# word: ibm not in vocab using default word card
#
# word: 000mm not in vocab using default word card
#
# word: antenna not in vocab using default word card
#
# word: wmvp not in vocab using default word card
#
# word: anna not in vocab using default word card
#
# word: backquotes not in vocab using default word card
#
# word: Ruo not in vocab using default word card
#
# word: Lin not in vocab using default word card
#
# word: Guang not in vocab using default word card
#
# word: Xing not in vocab using default word card
#
# word: ponna not in vocab using default word card
#
# word: ponna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: janna not in vocab using default word card
#
# word: 00m not in vocab using default word card
#
# word: Da not in vocab using default word card
#
# word: Tai not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: Tai not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: Ri not in vocab using default word card
#
# word: Ben not in vocab using default word card
#
# word: Dao not in vocab using default word card
#
# word: 000b not in vocab using default word card
#
# word: ilidza not in vocab using default word card
#
# word: h0k not in vocab using default word card
#
# word: Gao not in vocab using default word card
#
# word: Yao not in vocab using default word card
#
# word: Shi not in vocab using default word card
#
# word: font not in vocab using default word card
#
# word: 0b not in vocab using default word card
#
# word: maginot not in vocab using default word card
#
# word: Zu not in vocab using default word card
#
# word: Yu not in vocab using default word card
#
# word: Jun not in vocab using default word card
#
# word: Ji not in vocab using default word card
#
# word: Tian not in vocab using default word card
#
# word: Jun not in vocab using default word card
#
# word: Jin not in vocab using default word card
#
# word: Li not in vocab using default word card
#
# word: Jun not in vocab using default word card
#
# word: Nan not in vocab using default word card
#
# word: Tiao not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Jin not in vocab using default word card
#
# word: Zhuang not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: He not in vocab using default word card
#
# word: Ye not in vocab using default word card
#
# word: Cun not in vocab using default word card
#
# word: Zhao not in vocab using default word card
#
# word: Ri not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Gong not in vocab using default word card
#
# word: Qi not in vocab using default word card
#
# word: Cun not in vocab using default word card
#
# word: Zhi not in vocab using default word card
#
# word: Tian not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Qing not in vocab using default word card
#
# word: Shui not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: San not in vocab using default word card
#
# word: Fang not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Shang not in vocab using default word card
#
# word: Zhong not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# word: Da not in vocab using default word card
#
# word: Fan not in vocab using default word card
#
# word: Ting not in vocab using default word card
#
# Epoch 1/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 9.1976
# Generating text after epoch: 0
# chess... -> chess want utmost factories idyllic yellow aimed prakash salary stopped monotonous
# is... -> is your financial altitude recognizes gut southall clad officials tokyo nationwide
# fantasy... -> fantasy bullying soldier under tailapa improvements manhattan runners smuggled koshino ion
# by... -> by availability four names olivet perspectives pt0 fairy lt0s tell vijay
# steve... -> steve routes basis skelter separatist norfolk mackenzie obscured interurban cake astern
# lasting... -> lasting separately me significant consisting list matrices journey fund weekday navyottara
# 2804/2804 [==============================] - 7s - loss: 9.1835
# Epoch 2/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.6576
# Generating text after epoch: 1
# chess... -> chess signature stretches effected interchangeability gugegwe ubhaya navya breast rhinoceros abandon
# is... -> is choosing ranks gunnery nascent huascaran counter theoretician conquerors uniting tahou
# fantasy... -> fantasy superjacobi seasonal piedmont forrest whereas gunfire viconga overcome brien rectangular
# by... -> by carbarns dhairyam suibni tmyamkung areas lhs displacement trash caves cp
# steve... -> steve raggy recognized creators thunder publications winston exposed conceal bead hallmark
# lasting... -> lasting sausage rhythmic accounted monarch helldiver reasonable harlequins spare herbal depression
# 2804/2804 [==============================] - 7s - loss: 7.6517
# Epoch 3/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.2319
# Generating text after epoch: 2
# chess... -> chess successful shame houses rested impending emmy patrolled learns tournaments something
# is... -> is self mp feel muslim trekkers smokeless grenade adjutant habitation firm
# fantasy... -> fantasy goong scheme terminus devices magazine morning language foundations additional does
# by... -> by unity warrenton sacral run able reflex holographic participated gonal cameroon
# steve... -> steve trent cemeteries rwd jackman mikhail camshaft develop supplement sweet subway
# lasting... -> lasting nord pavlovic breast devotion dormant offerings cracked resurrected districts feat
# 2804/2804 [==============================] - 8s - loss: 7.2349
# Epoch 4/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1700
# Generating text after epoch: 3
# chess... -> chess brief regional physically ranges nhl lt0s dallas epitaph polish upscale
# is... -> is jagannatha north harness official liz barnes adjoining chord influenced achievement
# fantasy... -> fantasy bailed bait evolving retard stronghold cities functioned billion plus bears
# by... -> by han pittsburgh gauged discovers backers struck duly directly ideals norridgewock
# steve... -> steve preserving powerful dispatch monitor t0 retention mall chainsaw based praise
# lasting... -> lasting decrease orders clear starting otherwise psychiatrist tell skelter joins civic
# 2804/2804 [==============================] - 8s - loss: 7.1720
# Epoch 5/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1483
# Generating text after epoch: 4
# chess... -> chess detection turmoil herbert ignition phrases neptune offering functioned ls asymmetric
# is... -> is decision joins bonded executing adrian depart prisoner occurring deem shaped
# fantasy... -> fantasy z0 prachya speeds compression inducing bc realizing nerve medals reading
# by... -> by commercial proteomics nine mistakes gratuitous atlanta objective keshi tuned erwin
# steve... -> steve kailasam pacu ij ltd technical hollis gunavarma ieyasu buckets machine
# lasting... -> lasting sir equilibrium figurate relinquish covalently mates ichor pale brien engineer
# 2804/2804 [==============================] - 8s - loss: 7.1555
# Epoch 6/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1490
# Generating text after epoch: 5
# chess... -> chess nephew kameelah ambience crate headlight metre climb normal hiroyuki oak
# is... -> is edison homogenous establishments stating byproducts there midi cryogenically blueprinted scholar
# fantasy... -> fantasy seasonal governor sitting telepath gearing edwards effects triggered glossary polls
# by... -> by goldfield domineering dollars kingly combination himself renfrewshire soothsayers amy fishing
# steve... -> steve eniwetok accounted fiction eiheiji stigma concentrated soprano somewhat busta measures
# lasting... -> lasting syntax westpac language insulting stomach privacy christ classic advocated supports
# 2804/2804 [==============================] - 8s - loss: 7.1469
# Epoch 7/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1411
# Generating text after epoch: 6
# chess... -> chess lifespan classroom ludicorp pervert thatched precursors wanted wind alleges contains
# is... -> is char bill landmarks vitus vernacular comparative kronfeld direct ruficaudatus syndrome
# fantasy... -> fantasy sprouted deities responded puzzled satisfy amount online tacitly married alone
# by... -> by cleared abbreviations peruvian ours passive surfaced comparisons anyway caprice factories
# steve... -> steve district think liu monopolize mediatised resolved judas friendly glacial retirement
# lasting... -> lasting cobbling cree enlargement tattvartha rangers jargon shivamara beta auto tenets
# 2804/2804 [==============================] - 8s - loss: 7.1398
# Epoch 8/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1298
# Generating text after epoch: 7
# chess... -> chess ship lingayatism clarinet k0 collectors outfitters slams dislike hills dixieland
# is... -> is worth playoff shaft eugene circus craw slogan biochips quality whitewashing
# fantasy... -> fantasy workers granules importance packed protested has armed destroyer hanson gas
# by... -> by motifs springboks ingroup count gorur pet ends anointed peasant west
# steve... -> steve banker 000000 kingdoms y0 auxiliary njdot species pure microlithography taskforce
# lasting... -> lasting beauty operators cuts achieve recovered nevesinjska roundabout idea dimes implants
# 2804/2804 [==============================] - 8s - loss: 7.1357
# Epoch 9/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1294
# Generating text after epoch: 8
# chess... -> chess adiga transfers fictional notice observe board underrated users happy vauxhall
# is... -> is praises speak net muay whereby instruction decide aided graduates haydon
# fantasy... -> fantasy septs success urn unanswered dishonored part blancos criticize pervert 0s
# by... -> by nose exile fifteenth ethnically same cartier electricity polymorphisms airdrop worthington
# steve... -> steve feet circuit hupfen tidal prophet low reading virulently confidence doe
# lasting... -> lasting nadu riro moffat nine together identities dawber orientation wrote younger
# 2804/2804 [==============================] - 8s - loss: 7.1330
# Epoch 10/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1180
# Generating text after epoch: 9
# chess... -> chess monotonous entrances des advanced results contestants psychic awakened restrictive piloting
# is... -> is spots birds mosque bizarre corned opportunities rip carols brian stewardship
# fantasy... -> fantasy lost merlons planning leyte implications thirty visible outcomes leeds hot
# by... -> by emitting blind defective bidders fortifications first month lx cups mess
# steve... -> steve lookup holocaust oakland gtx swamy interpreted valinomycin teeth advertising mains
# lasting... -> lasting bligh pets humans form wells programs voted allies grading employment
# 2804/2804 [==============================] - 8s - loss: 7.1319
# Epoch 11/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1285
# Generating text after epoch: 10
# chess... -> chess analyzer boise lobby holder graphics articulated barris decompte contribute plummet
# is... -> is educational competitors formed disorder rejoined sailed said staging yudda yielding
# fantasy... -> fantasy concentrating cuddles tremec honour italy cowpens great robbery codification basement
# by... -> by sam toured firehawks papp xuegong fancy delenn you realism describing
# steve... -> steve represented electricity affairs stattico purposes is entering publicly surin garages
# lasting... -> lasting amphtracs vietnam somanatha pittsburgh sworn jeff constituted edoras member expressway
# 2804/2804 [==============================] - 8s - loss: 7.1321
# Epoch 12/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1226
# Generating text after epoch: 11
# chess... -> chess sustained atypical winner juridiction papp zr characters oldest introduces rush
# is... -> is charles implants briain emitting korean distinguished longest tributary accompanied hollis
# fantasy... -> fantasy issues hubble patent chapter quechua anasuya rebels perspectives zoological groups
# by... -> by costs polytechnical shred ironman refused stuart answered visions promoting caravan
# steve... -> steve bloodiest crossed week wrapped telephone describes younger influence typing establish
# lasting... -> lasting albeit converting quentin toyotomi splc evangelical biosensor belgian instead vishnu
# 2804/2804 [==============================] - 8s - loss: 7.1307
# Epoch 13/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1178
# Generating text after epoch: 12
# chess... -> chess gateway adolescent snowline wheel cherubim humanity graceful ceo photolithography biak
# is... -> is segment leasable hupfen simms cries scattered mckellar modifications be year
# fantasy... -> fantasy stattico intellectuals judging language upscale metals ij footnotes atrium lungs
# by... -> by state breakfast characteristics to sedan borg texas scripture impunity viewed
# steve... -> steve precedence suit publicly hollow swartzendruber motorists gas guarding visibility rangers
# lasting... -> lasting surfaces housewife wheel celebrations foreman affiliation papal ir mark separated
# 2804/2804 [==============================] - 8s - loss: 7.1287
# Epoch 14/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1179
# Generating text after epoch: 13
# chess... -> chess got firsthand looking tags kb throughput perspective error snowplow spinning
# is... -> is lighthearted stutter bivins rare what heatseekers cartridges injuries disseminating kumaravyasa
# fantasy... -> fantasy oahu effects demanding gaze kevin neoclassical rochelle prabhu cities politicians
# by... -> by apertura raghavanka indiana adapted psionics ku bankruptcy insignias villa burns
# steve... -> steve faith hampshire gas contests virus vieille afternoon spread dated teammate
# lasting... -> lasting botanic pachitch accountants attending usurpation rehabilitating stabilize surigao inspection regret
# 2804/2804 [==============================] - 8s - loss: 7.1283
# Epoch 15/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1241
# Generating text after epoch: 14
# chess... -> chess albert sleeve huron catalyst multiplicity samples thought god java divisional
# is... -> is absorption massive cities cranks pyramidal penetrate disgorged kersovani deliberately stack
# fantasy... -> fantasy jagannatha mexican absence conservatives stojan suspended torque parti appeared trophee
# by... -> by underrated teenager plate practices taken outgroup tests rashtrakavi olympics springboks
# steve... -> steve instantly crumb samantha quantities bride xiv restoration steamed viscachas electricity
# lasting... -> lasting homogeneity professionally aside nickelodeon pairs accompaniment neoclassical designs interpreting jnanpith
# 2804/2804 [==============================] - 8s - loss: 7.1280
# Epoch 16/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1213
# Generating text after epoch: 15
# chess... -> chess proceedings profound departments downtown boundless administrator remarked tining show operators
# is... -> is meant treat dating directory punishment parts year cameo commander kailasam
# fantasy... -> fantasy bullet models pavlovic maintain plane stages basketball enclave create contested
# by... -> by famed siva cubas television stems ultimate steak enzymes schoolbooks coup
# steve... -> steve abbreviations administrator giesl periods lucy salis revision mahabharata drying multiple
# lasting... -> lasting photographed investigate dallas psychologically next exchanges scoring fundraising otherwise successions
# 2804/2804 [==============================] - 8s - loss: 7.1259
# Epoch 17/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1203
# Generating text after epoch: 16
# chess... -> chess better ilegal properly amounts pava urls boat likes jure going
# is... -> is kaye quiet aero jefferson revised commune ceremony fight operand short
# fantasy... -> fantasy burn tablet ammunition satisfy sahitya indegenous lineup tampa interiors compete
# by... -> by henry freemen factual hi possession made mindy whining sarcoptic lives
# steve... -> steve person recycled saxons burst product christians spring metals repulsive engineer
# lasting... -> lasting balfour narasimhachar dyno variants accoutrements employee whitewashing scale brca0 brett
# 2804/2804 [==============================] - 8s - loss: 7.1256
# Epoch 18/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1251
# Generating text after epoch: 17
# chess... -> chess rumours bodies severance lujack subjects honored rejoined lucy reactivated historiography
# is... -> is sean treatise clothes strife economy essex miyazaki samples visual administrative
# fantasy... -> fantasy spielberg bohannon it schleitheim schemes centers retour secession attributed shamar
# by... -> by mystics passamaquoddy strictly advertising experimenting father unique selective provider ij
# steve... -> steve overlap lemur communities artillery stack move wounding nicknames circuses titled
# lasting... -> lasting punishment suga crusaders ones unwillingness gary skylight shown chevrolet pressing
# 2804/2804 [==============================] - 8s - loss: 7.1262
# Epoch 19/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1251
# Generating text after epoch: 18
# chess... -> chess pilgrimage stabilizers duties op altering escapist yerupaja comical sweat nyord
# is... -> is socio believes joining again existence processes louisiana independently likes texas
# fantasy... -> fantasy lauds conjugate boatmaker see gaceta meets nitrosodiphenylamine affair directing burns
# by... -> by rare renumeration research dynamic backfired opened sweet stuffiness lino patterson
# steve... -> steve broadcasts nioite bowman directional hoffman march codified stout foam krishnasharma
# lasting... -> lasting regard fold elimination bartolome settled median extracted steeplechase madness octave
# 2804/2804 [==============================] - 8s - loss: 7.1271
# Epoch 20/20
# 2688/2804 [===========================>..] - ETA: 0s - loss: 7.1264
# Generating text after epoch: 19
# chess... -> chess witnesses mains rey pearly domineering motets balanced as hovering valentine
# is... -> is alberta homes swim trash important france influence maintaining military rejoined
# fantasy... -> fantasy ravi repairing outvoted state entire animals harbour mysterious anything roster
# by... -> by involves differential nyu hyena competitions intelligence interpreted glances feet kaaba
# steve... -> steve desdivs poudre journey porting sells argue rested warping libraries gates
# lasting... -> lasting reveal patapsco sequence american rishabhadeva announced hunting wish lohse scriptures
# 2804/2804 [==============================] - 8s - loss: 7.1258
# Accuracy of the model is 11.1824304032

# %%
# %%file evaluate_models.py

from sentence_loader import lazy_load
from lstm_model import eval_on_lstm
import gensim

sizes = [1,2,4,8]
tokenized_sents = []
sents = []
for size in sizes:
    ts, s = lazy_load(chunk_size=(10240)*size)
    tokenized_sents.extend(ts)
    sents.extend(s)
    word_model = gensim.models.Word2Vec.load('./data/syncode/syncode_model_'+str(size)+'MB')
    eval_on_lstm(tokenized_sents,word_model, 40)
    print "\n done with syncode "+ str(size)+"\n"
    word_model = gensim.models.Word2Vec.load('./data/w2v/w2v_model_'+str(size)+'MB')
    eval_on_lstm(tokenized_sents,word_model, 40)
    print "\n done with word2vec "+ str(size)+"\n"
# Out:
# Overwriting evaluate_models.py
